# %%
# %pip install pandas
# %pip install numpy
# %pip install scipy
# %pip install matplotlib
# %pip install statsmodels
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats
# import scipy.stats as stats

# %%
ai_survey_employment = pd.read_csv("../../data/clean/Evaluating_Businesses_Thoughts_on_Employment_Totals_with_AI.csv")

utilization_data = pd.read_csv("../../data/clean/Evaluate_Change_in_Utilization_Rates_All.csv")

# %%
# current_data_mask = utilization_data['Year'].isin([2025,2024])

# utilization_data = utilization_data[(current_data_mask)]
# utilization_data = utilization_data.reset_index(drop=True)

# %%
combo = ai_survey_employment.merge(utilization_data, left_on="Business characteristics", right_on="North American Industry Classification System (NAICS)",
          suffixes=('_2025', '_2024'))

# %%
# utilization_data = utilization_data[~utilization_data['Normality'].eq("Normal")]
combo = combo[["Business characteristics","REF_DATE", "VALUE", "Quarter", "Median by Quarter", "Lower Bound", "Upper Bound", "ZScore", "Median by Quarter"]]

combo
# Out:
#     Business characteristics    REF_DATE  VALUE  Quarter  Median by Quarter  \
# 0          Construction [23]  1987-01-01   84.4        1              87.40
# 1          Construction [23]  1987-04-01   88.0        2              86.80
# 2          Construction [23]  1987-07-01   90.4        3              87.40
# 3          Construction [23]  1987-10-01   91.0        4              87.75
# 4          Construction [23]  1988-01-01   89.9        1              87.40
# ..                       ...         ...    ...      ...                ...
# 303    Manufacturing [31-33]  2024-04-01   77.8        2              81.10
# 304    Manufacturing [31-33]  2024-07-01   77.9        3              80.80
# 305    Manufacturing [31-33]  2024-10-01   78.0        4              80.60
# 306    Manufacturing [31-33]  2025-01-01   77.4        1              80.70
# 307    Manufacturing [31-33]  2025-04-01   76.7        2              81.10
#
#      Lower Bound  Upper Bound
# ...

# %% [markdown]
# No abnromal changes in utilization rate in 2024 or 2025 indicating AI didn't drastically impact industry utilization rates.

# %%
combo.to_csv('../../data/clean/Evaluated_Industries_and_Utilization_Rates.csv',index=True)
